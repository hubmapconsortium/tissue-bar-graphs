# %%
#path to kidney hubmap csv
# changed to match path running in root folder
PATH = "/csv/Kidney_HuBMAP_Portal"

# %%
import os
import pandas as pd

dict = {}

for file in os.listdir(PATH):
    data = pd.read_csv(os.path.join(PATH,file))[['cell_type','count']]
    data.index = data['cell_type']
    data = data["count"]
    
    dict[file[:-4]] = pd.Series(data).to_dict()

# %%
unique_cts = []
for key in dict.keys():
    unique_cts.extend(list(dict[key].keys()))
unique_cts = set(unique_cts)

# %%
ct_counts_mat = pd.DataFrame(data=[dict[key] for key in dict.keys()],columns=list(unique_cts))

# %%
ct_counts_mat
# Out:
#     Connecting Tubule Intercalated Type A  Glomerular Capillary Endothelial  \
# 0                                     NaN                               NaN
# 1                                     2.0                             165.0
# 2                                     NaN                               NaN
# 3                                     NaN                               1.0
# 4                                     NaN                               NaN
# ..                                    ...                               ...
# 72                                    NaN                               1.0
# 73                                    NaN                               NaN
# 74                                    NaN                               NaN
# 75                                    NaN                               NaN
# 76                                    NaN                               NaN
#
#     Macula Densa  Non-classical monocyte  Descending Thin Limb Type 2  \
# 0            NaN                     1.0                          7.0
# 1           78.0                     1.0                        636.0
# 2            3.0                     NaN                          2.0
# 3           26.0                     NaN                         39.0
# 4            9.0                     NaN                          2.0
# ..           ...                     ...                          ...
# 72         192.0                     NaN                         24.0
# 73           NaN                     NaN                          NaN
# 74           NaN                     2.0                          NaN
# 75           NaN                     NaN                          NaN
# 76           NaN                     NaN                          NaN
#
#     Fibroblast  Vascular Smooth Muscle / Pericyte  \
# 0         16.0                                9.0
# 1        777.0                               22.0
# 2         32.0                               11.0
# 3         16.0                               13.0
# 4         45.0                                NaN
# ..         ...                                ...
# 72        21.0                               11.0
# 73       165.0                               34.0
# 74       852.0                              608.0
# 75         NaN                                NaN
# 76       206.0                              257.0
#
#     Descending Thin Limb Type 3  Medullary Fibroblast  \
# 0                         101.0                 277.0
# 1                          60.0                  47.0
# 2                          20.0                 254.0
# 3                          17.0                  15.0
# 4                          19.0                  16.0
# ..                          ...                   ...
# 72                          6.0                  41.0
# 73                          NaN                 130.0
# 74                          1.0                 347.0
# 75                          NaN                   NaN
# 76                          NaN                  61.0
#
#     Renin-positive Juxtaglomerular Granular  ...  Intercalated Type B  \
# 0                                       NaN  ...                  2.0
# 1                                       1.0  ...                185.0
# 2                                       1.0  ...                 30.0
# 3                                       3.0  ...                  1.0
# 4                                       NaN  ...                  NaN
# ..                                      ...  ...                  ...
# 72                                      NaN  ...                  NaN
# 73                                      NaN  ...                  NaN
# 74                                      1.0  ...                  NaN
# 75                                      NaN  ...                  NaN
# 76                                      2.0  ...                  NaN
#
#     Peritubular Capilary Endothelial   Monocyte-derived  \
# 0                                 3.0               2.0
# 1                               130.0              18.0
# 2                                 3.0               1.0
# 3                                51.0               NaN
# 4                                 NaN               NaN
# ..                                ...               ...
# 72                                3.0               NaN
# 73                                8.0               NaN
# 74                                2.0               2.0
# 75                                NaN               NaN
# 76                               17.0               NaN
#
#     Proximal Tubule Epithelial Segment 1    T  \
# 0                                    NaN  NaN
# 1                                 1903.0  1.0
# 2                                    1.0  NaN
# 3                                    NaN  NaN
# 4                                    NaN  NaN
# ..                                   ...  ...
# 72                                   NaN  NaN
# 73                                   NaN  NaN
# 74                                   NaN  1.0
# 75                                   NaN  NaN
# 76                                   1.0  4.0
#
#     Proximal Tubule Epithelial Segment 3  Connecting Tubule  Natural Killer T  \
# 0                                    3.0               2592               NaN
# 1                                  785.0                859               NaN
# 2                                    6.0               3665               NaN
# 3                                    2.0               2294               NaN
# 4                                    2.0                 17               NaN
# ..                                   ...                ...               ...
# 72                                   1.0               1270               NaN
# 73                                   NaN                497               NaN
# 74                                   1.0               6481               NaN
# 75                                   NaN                 32               NaN
# 76                                   2.0                211               NaN
#
#     Parietal Epithelial  Proximal Tubule Epithelial Segment 2
# 0                  50.0                                   NaN
# 1                  99.0                                   NaN
# 2                  25.0                                   NaN
# 3                  13.0                                   NaN
# 4                   NaN                                   NaN
# ..                  ...                                   ...
# 72                 11.0                                   NaN
# 73                  NaN                                   NaN
# 74                  7.0                                   NaN
# 75                  NaN                                   NaN
# 76                 23.0                                   NaN
#
# [77 rows x 49 columns]

# %%
ct_counts_mat['HuBMAP_dataset_id'] = list(dict.keys())

# %%
ct_counts_mat.iloc[:,:-1] = ct_counts_mat.iloc[:,:-1].fillna(0).astype(int)
# Out:
# /var/folders/4p/h6qyq5d960lc6ynv7nz6vplr0000gn/T/ipykernel_7486/133977190.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ct_counts_mat.iloc[:,:-1] = ct_counts_mat.iloc[:,:-1].fillna(0).astype(int)

# %%
ct_counts_mat
# Out:
#     Connecting Tubule Intercalated Type A  Glomerular Capillary Endothelial  \
# 0                                       0                                 0
# 1                                       2                               165
# 2                                       0                                 0
# 3                                       0                                 1
# 4                                       0                                 0
# ..                                    ...                               ...
# 72                                      0                                 1
# 73                                      0                                 0
# 74                                      0                                 0
# 75                                      0                                 0
# 76                                      0                                 0
#
#     Macula Densa  Non-classical monocyte  Descending Thin Limb Type 2  \
# 0              0                       1                            7
# 1             78                       1                          636
# 2              3                       0                            2
# 3             26                       0                           39
# 4              9                       0                            2
# ..           ...                     ...                          ...
# 72           192                       0                           24
# 73             0                       0                            0
# 74             0                       2                            0
# 75             0                       0                            0
# 76             0                       0                            0
#
#     Fibroblast  Vascular Smooth Muscle / Pericyte  \
# 0           16                                  9
# 1          777                                 22
# 2           32                                 11
# 3           16                                 13
# 4           45                                  0
# ..         ...                                ...
# 72          21                                 11
# 73         165                                 34
# 74         852                                608
# 75           0                                  0
# 76         206                                257
#
#     Descending Thin Limb Type 3  Medullary Fibroblast  \
# 0                           101                   277
# 1                            60                    47
# 2                            20                   254
# 3                            17                    15
# 4                            19                    16
# ..                          ...                   ...
# 72                            6                    41
# 73                            0                   130
# 74                            1                   347
# 75                            0                     0
# 76                            0                    61
#
#     Renin-positive Juxtaglomerular Granular  ...  \
# 0                                         0  ...
# 1                                         1  ...
# 2                                         1  ...
# 3                                         3  ...
# 4                                         0  ...
# ..                                      ...  ...
# 72                                        0  ...
# 73                                        0  ...
# 74                                        1  ...
# 75                                        0  ...
# 76                                        2  ...
#
#     Peritubular Capilary Endothelial   Monocyte-derived  \
# 0                                   3                 2
# 1                                 130                18
# 2                                   3                 1
# 3                                  51                 0
# 4                                   0                 0
# ..                                ...               ...
# 72                                  3                 0
# 73                                  8                 0
# 74                                  2                 2
# 75                                  0                 0
# 76                                 17                 0
#
#     Proximal Tubule Epithelial Segment 1  T  \
# 0                                      0  0
# 1                                   1903  1
# 2                                      1  0
# 3                                      0  0
# 4                                      0  0
# ..                                   ... ..
# 72                                     0  0
# 73                                     0  0
# 74                                     0  1
# 75                                     0  0
# 76                                     1  4
#
#     Proximal Tubule Epithelial Segment 3  Connecting Tubule  Natural Killer T  \
# 0                                      3               2592                 0
# 1                                    785                859                 0
# 2                                      6               3665                 0
# 3                                      2               2294                 0
# 4                                      2                 17                 0
# ..                                   ...                ...               ...
# 72                                     1               1270                 0
# 73                                     0                497                 0
# 74                                     1               6481                 0
# 75                                     0                 32                 0
# 76                                     2                211                 0
#
#     Parietal Epithelial  Proximal Tubule Epithelial Segment 2  \
# 0                    50                                     0
# 1                    99                                     0
# 2                    25                                     0
# 3                    13                                     0
# 4                     0                                     0
# ..                  ...                                   ...
# 72                   11                                     0
# 73                    0                                     0
# 74                    7                                     0
# 75                    0                                     0
# 76                   23                                     0
#
#     HuBMAP_dataset_id
# 0     HBM892.HQDK.764
# 1     HBM537.GVTL.683
# 2     HBM932.TBDW.952
# 3     HBM679.ZVHH.999
# 4     HBM837.TDQQ.538
# ..                ...
# 72    HBM476.ZWMS.768
# 73    HBM254.SXWG.373
# 74    HBM742.PSCP.565
# 75    HBM843.QHNR.854
# 76    HBM772.WGBN.852
#
# [77 rows x 50 columns]

# %%
ct_counts_mat.to_csv("ct_counts_mat.csv")

# %%
#https://docs.google.com/spreadsheets/d/1cwxztPg9sLq0ASjJ5bntivUk6dSKHsVyR1bE6bXvMkY/edit#gid=1529271254
impdata = pd.read_csv("IMPSHEET_1.csv")
impdata.columns = impdata.iloc[0,:]
impdata = impdata.iloc[1:,[2,3]]

# %%
impdata['dataset_id'] = impdata.apply(lambda row: row['dataset_id'][:-4],axis=1)

# %%
impdata
# Out:
# 0                                     dataset_id HuBMAP_tissue_block_id
# 1           1b9d8702-5af8-4142-85ed-020eb06ec4f6                    NaN
# 2           53d208b0-2cfd-4366-9866-c3c6114081bc                    NaN
# 3           53d208b0-2cfd-4366-9866-c3c6114081bc                    NaN
# 4             CODEX_Florida_19-003-lymph-node-R2                    NaN
# 5     CODEX_Florida_20-008-lymphnode10_righthalf                    NaN
# ...                                          ...                    ...
# 1258                                 HBM992.XNZH        HBM833.VZTL.864
# 1259                                 HBM993.ZZWK        HBM528.ZLVW.967
# 1260                                 HBM996.MDQH        HBM432.KLVR.258
# 1261                                 HBM996.MDQH        HBM545.TFNG.256
# 1262                                 HBM999.CXFH        HBM876.QFMP.836
#
# [1262 rows x 2 columns]

# %%
final = pd.merge(ct_counts_mat,impdata,left_on="HuBMAP_dataset_id", right_on="dataset_id", how="left").drop("dataset_id",axis=1).drop("HuBMAP_dataset_id", axis=1)

# %%
final_agg = final.groupby(by=['HuBMAP_tissue_block_id']).agg(sum)

# %%
from numpy import dot
from numpy.linalg import norm

def cos_sim(a,b):
   return dot(a, b)/(norm(a)*norm(b))

# %%
cos_sim_df = pd.DataFrame(columns=final_agg.index)

# %%
cos_sim_df["HuBMAP_tissue_block_id"] = final_agg.index.tolist()

# %%
def find_cos_sim(row):
    arr = []
    for col in row.index:
        if col != "HuBMAP_tissue_block_id":
            arr.append(cos_sim(final_agg.loc[col],final_agg.loc[row["HuBMAP_tissue_block_id"]]))
    return arr

# %%
cos_sim_df = cos_sim_df.apply(lambda row: find_cos_sim(row), axis=1)

# %%
import numpy as np

# %%
cos_sim_df = np.array(cos_sim_df.tolist())

# %%
cos_sim_df = pd.DataFrame(cos_sim_df,index=final_agg.index.tolist(),columns=final_agg.index.tolist())

# %%
cos_sim_df
# Out:
#                  HBM224.HCFB.249  HBM297.PFXV.394  HBM336.BZXG.436  \
# HBM224.HCFB.249         1.000000         0.726560         0.812948
# HBM297.PFXV.394         0.726560         1.000000         0.624926
# HBM336.BZXG.436         0.812948         0.624926         1.000000
# HBM339.DBQF.784         0.964021         0.751506         0.732329
# HBM345.QSPF.289         0.622300         0.431613         0.528421
# HBM434.JDFP.839         0.686334         0.266264         0.701974
# HBM449.THVK.739         0.851887         0.497374         0.724251
# HBM453.BKZB.338         0.607852         0.202624         0.762596
# HBM455.PRVR.965         0.607731         0.963233         0.593667
# HBM486.QXHD.874         0.830345         0.805444         0.959393
# HBM496.GJFX.393         0.552710         0.232306         0.642864
# HBM525.HTJF.586         0.912545         0.690996         0.530433
# HBM534.PQDR.545         0.695956         0.272452         0.847522
# HBM538.RWLX.332         0.429886         0.327690         0.189530
# HBM547.QLDF.845         0.902269         0.789270         0.922058
# HBM556.CFNP.485         0.750155         0.923987         0.826425
# HBM557.PWFN.956         0.671683         0.975945         0.652995
# HBM562.WMRL.498         0.698820         0.201857         0.473430
# HBM566.KXSQ.967         0.628994         0.957908         0.636365
# HBM574.LFRK.262         0.783939         0.911117         0.864583
# HBM587.VWCF.356         0.684122         0.965308         0.707710
# HBM635.PSTJ.637         0.705959         0.443442         0.511181
# HBM638.HSFV.957         0.813676         0.885568         0.822104
# HBM642.VZNT.722         0.641257         0.447584         0.176916
# HBM653.SFTB.462         0.438356         0.171567         0.013856
# HBM667.TFXK.856         0.833451         0.916311         0.546587
# HBM695.TGJS.338         0.121386         0.051369         0.013089
# HBM748.GDSK.748         0.733742         0.939715         0.795135
# HBM752.DHVB.758         0.671477         0.987388         0.592808
# HBM757.NMDS.629         0.705883         0.322499         0.754100
# HBM782.RNDZ.677         0.731624         0.949334         0.703486
# HBM788.KSZC.942         0.773131         0.884643         0.858605
# HBM796.XJWH.729         0.780955         0.863848         0.875423
# HBM833.VZTL.864         0.722517         0.367595         0.876893
# HBM838.FRWC.772         0.945929         0.653679         0.733389
# HBM853.SNJJ.892         0.630125         0.191058         0.721874
# HBM876.SJWP.278         0.728003         0.986850         0.659709
# HBM937.HPQL.829         0.951797         0.537959         0.712862
# HBM964.XZCR.478         0.310534         0.267018         0.310432
# HBM974.MTJZ.548         0.570259         0.279662         0.684777
# HBM979.SSNH.934         0.741881         0.438100         0.245108
# HBM987.ZCTQ.736         0.731349         0.448241         0.396849
#
#                  HBM339.DBQF.784  HBM345.QSPF.289  HBM434.JDFP.839  \
# HBM224.HCFB.249         0.964021         0.622300         0.686334
# HBM297.PFXV.394         0.751506         0.431613         0.266264
# HBM336.BZXG.436         0.732329         0.528421         0.701974
# HBM339.DBQF.784         1.000000         0.633293         0.628647
# HBM345.QSPF.289         0.633293         1.000000         0.615229
# HBM434.JDFP.839         0.628647         0.615229         1.000000
# HBM449.THVK.739         0.888597         0.711692         0.747269
# HBM453.BKZB.338         0.569677         0.734953         0.738808
# HBM455.PRVR.965         0.627943         0.362461         0.117423
# HBM486.QXHD.874         0.777123         0.526571         0.567737
# HBM496.GJFX.393         0.432464         0.782379         0.661459
# HBM525.HTJF.586         0.934347         0.497052         0.527103
# HBM534.PQDR.545         0.634757         0.642576         0.783913
# HBM538.RWLX.332         0.596120         0.620099         0.365634
# HBM547.QLDF.845         0.854961         0.565312         0.580431
# HBM556.CFNP.485         0.731287         0.465235         0.460609
# HBM557.PWFN.956         0.682664         0.408300         0.204219
# HBM562.WMRL.498         0.748103         0.661966         0.714135
# HBM566.KXSQ.967         0.638930         0.376673         0.219066
# HBM574.LFRK.262         0.755994         0.486373         0.426099
# HBM587.VWCF.356         0.686773         0.420243         0.260868
# HBM635.PSTJ.637         0.800307         0.691780         0.581723
# HBM638.HSFV.957         0.804149         0.500920         0.414042
# HBM642.VZNT.722         0.772784         0.532733         0.394414
# HBM653.SFTB.462         0.570277         0.454597         0.348466
# HBM667.TFXK.856         0.867591         0.468881         0.331445
# HBM695.TGJS.338         0.279086         0.458975         0.207662
# HBM748.GDSK.748         0.715571         0.492795         0.413265
# HBM752.DHVB.758         0.699575         0.393885         0.189130
# HBM757.NMDS.629         0.725572         0.759639         0.749652
# HBM782.RNDZ.677         0.739347         0.439010         0.424803
# HBM788.KSZC.942         0.737251         0.475662         0.422168
# HBM796.XJWH.729         0.739190         0.481230         0.443870
# HBM833.VZTL.864         0.651527         0.741928         0.756723
# HBM838.FRWC.772         0.963035         0.735654         0.745487
# HBM853.SNJJ.892         0.520730         0.773992         0.780375
# HBM876.SJWP.278         0.744276         0.434118         0.246832
# HBM937.HPQL.829         0.925017         0.549471         0.713221
# HBM964.XZCR.478         0.389799         0.586168         0.392031
# HBM974.MTJZ.548         0.599600         0.643909         0.615197
# HBM979.SSNH.934         0.789324         0.390718         0.456790
# HBM987.ZCTQ.736         0.846331         0.636534         0.557298
#
#                  HBM449.THVK.739  HBM453.BKZB.338  HBM455.PRVR.965  \
# HBM224.HCFB.249         0.851887         0.607852         0.607731
# HBM297.PFXV.394         0.497374         0.202624         0.963233
# HBM336.BZXG.436         0.724251         0.762596         0.593667
# HBM339.DBQF.784         0.888597         0.569677         0.627943
# HBM345.QSPF.289         0.711692         0.734953         0.362461
# HBM434.JDFP.839         0.747269         0.738808         0.117423
# HBM449.THVK.739         1.000000         0.748056         0.380927
# HBM453.BKZB.338         0.748056         1.000000         0.160350
# HBM455.PRVR.965         0.380927         0.160350         1.000000
# HBM486.QXHD.874         0.685169         0.633632         0.792668
# HBM496.GJFX.393         0.592913         0.776860         0.196142
# HBM525.HTJF.586         0.736960         0.327938         0.529423
# HBM534.PQDR.545         0.826737         0.915166         0.216320
# HBM538.RWLX.332         0.623708         0.458824         0.231806
# HBM547.QLDF.845         0.754035         0.650444         0.754136
# HBM556.CFNP.485         0.562093         0.413962         0.903274
# HBM557.PWFN.956         0.446363         0.221386         0.993770
# HBM562.WMRL.498         0.824794         0.734412         0.045739
# HBM566.KXSQ.967         0.405324         0.192863         0.977743
# HBM574.LFRK.262         0.597276         0.474432         0.914262
# HBM587.VWCF.356         0.468892         0.279047         0.986579
# HBM635.PSTJ.637         0.771636         0.695340         0.332241
# HBM638.HSFV.957         0.632716         0.481623         0.875543
# HBM642.VZNT.722         0.676696         0.257881         0.281975
# HBM653.SFTB.462         0.499129         0.274739         0.007568
# HBM667.TFXK.856         0.604727         0.209788         0.833644
# HBM695.TGJS.338         0.317282         0.409244         0.005531
# HBM748.GDSK.748         0.544382         0.392500         0.939941
# HBM752.DHVB.758         0.436647         0.157556         0.988787
# HBM757.NMDS.629         0.904597         0.906820         0.249313
# HBM782.RNDZ.677         0.520053         0.273563         0.912527
# HBM788.KSZC.942         0.585632         0.473238         0.893071
# HBM796.XJWH.729         0.600206         0.501253         0.870336
# HBM833.VZTL.864         0.772459         0.952303         0.328369
# HBM838.FRWC.772         0.897413         0.687992         0.517446
# HBM853.SNJJ.892         0.721124         0.878497         0.129638
# HBM876.SJWP.278         0.498043         0.236380         0.983513
# HBM937.HPQL.829         0.843088         0.604781         0.383794
# HBM964.XZCR.478         0.598752         0.397354         0.231411
# HBM974.MTJZ.548         0.694527         0.897242         0.245595
# HBM979.SSNH.934         0.630281         0.176416         0.240496
# HBM987.ZCTQ.736         0.882114         0.488805         0.298985
#
#                  HBM486.QXHD.874  ...  HBM796.XJWH.729  HBM833.VZTL.864  \
# HBM224.HCFB.249         0.830345  ...         0.780955         0.722517
# HBM297.PFXV.394         0.805444  ...         0.863848         0.367595
# HBM336.BZXG.436         0.959393  ...         0.875423         0.876893
# HBM339.DBQF.784         0.777123  ...         0.739190         0.651527
# HBM345.QSPF.289         0.526571  ...         0.481230         0.741928
# HBM434.JDFP.839         0.567737  ...         0.443870         0.756723
# HBM449.THVK.739         0.685169  ...         0.600206         0.772459
# HBM453.BKZB.338         0.633632  ...         0.501253         0.952303
# HBM455.PRVR.965         0.792668  ...         0.870336         0.328369
# HBM486.QXHD.874         1.000000  ...         0.959929         0.778789
# HBM496.GJFX.393         0.554937  ...         0.453805         0.837396
# HBM525.HTJF.586         0.592691  ...         0.576207         0.428731
# HBM534.PQDR.545         0.717814  ...         0.579116         0.958340
# HBM538.RWLX.332         0.230389  ...         0.234980         0.344568
# HBM547.QLDF.845         0.960526  ...         0.923119         0.771652
# HBM556.CFNP.485         0.933496  ...         0.963786         0.572344
# HBM557.PWFN.956         0.835328  ...         0.909752         0.391885
# HBM562.WMRL.498         0.380984  ...         0.279837         0.654087
# HBM566.KXSQ.967         0.814162  ...         0.912101         0.358119
# HBM574.LFRK.262         0.969069  ...         0.983873         0.636400
# HBM587.VWCF.356         0.873122  ...         0.929621         0.446828
# HBM635.PSTJ.637         0.507501  ...         0.459656         0.619254
# HBM638.HSFV.957         0.925611  ...         0.924610         0.619460
# HBM642.VZNT.722         0.238379  ...         0.245883         0.232757
# HBM653.SFTB.462         0.020562  ...         0.008851         0.168260
# HBM667.TFXK.856         0.706826  ...         0.754056         0.345827
# HBM695.TGJS.338         0.013556  ...         0.009855         0.229987
# HBM748.GDSK.748         0.922375  ...         0.949688         0.557429
# HBM752.DHVB.758         0.789254  ...         0.862149         0.327066
# HBM757.NMDS.629         0.659858  ...         0.545456         0.894508
# HBM782.RNDZ.677         0.844845  ...         0.905343         0.433414
# HBM788.KSZC.942         0.954395  ...         0.998338         0.631069
# HBM796.XJWH.729         0.959929  ...         1.000000         0.655983
# HBM833.VZTL.864         0.778789  ...         0.655983         1.000000
# HBM838.FRWC.772         0.738777  ...         0.679016         0.734782
# HBM853.SNJJ.892         0.592416  ...         0.461072         0.907511
# HBM876.SJWP.278         0.837577  ...         0.898502         0.405949
# HBM937.HPQL.829         0.680042  ...         0.598124         0.670636
# HBM964.XZCR.478         0.311901  ...         0.292788         0.412990
# HBM974.MTJZ.548         0.605356  ...         0.510271         0.814985
# HBM979.SSNH.934         0.277168  ...         0.260728         0.219815
# HBM987.ZCTQ.736         0.409948  ...         0.375308         0.470966
#
#                  HBM838.FRWC.772  HBM853.SNJJ.892  HBM876.SJWP.278  \
# HBM224.HCFB.249         0.945929         0.630125         0.728003
# HBM297.PFXV.394         0.653679         0.191058         0.986850
# HBM336.BZXG.436         0.733389         0.721874         0.659709
# HBM339.DBQF.784         0.963035         0.520730         0.744276
# HBM345.QSPF.289         0.735654         0.773992         0.434118
# HBM434.JDFP.839         0.745487         0.780375         0.246832
# HBM449.THVK.739         0.897413         0.721124         0.498043
# HBM453.BKZB.338         0.687992         0.878497         0.236380
# HBM455.PRVR.965         0.517446         0.129638         0.983513
# HBM486.QXHD.874         0.738777         0.592416         0.837577
# HBM496.GJFX.393         0.539743         0.936034         0.259900
# HBM525.HTJF.586         0.887345         0.352600         0.661958
# HBM534.PQDR.545         0.691909         0.897263         0.306194
# HBM538.RWLX.332         0.670900         0.226655         0.301701
# HBM547.QLDF.845         0.813294         0.613658         0.817274
# HBM556.CFNP.485         0.667892         0.381543         0.931062
# HBM557.PWFN.956         0.582571         0.198279         0.992871
# HBM562.WMRL.498         0.853750         0.601587         0.185719
# HBM566.KXSQ.967         0.542329         0.164156         0.972282
# HBM574.LFRK.262         0.687891         0.435671         0.938440
# HBM587.VWCF.356         0.594057         0.247965         0.986168
# HBM635.PSTJ.637         0.875682         0.465223         0.433070
# HBM638.HSFV.957         0.730886         0.433447         0.911477
# HBM642.VZNT.722         0.773682         0.177080         0.400970
# HBM653.SFTB.462         0.648467         0.113768         0.123289
# HBM667.TFXK.856         0.775110         0.215198         0.899768
# HBM695.TGJS.338         0.413592         0.089977         0.037500
# HBM748.GDSK.748         0.654150         0.384279         0.958281
# HBM752.DHVB.758         0.593035         0.138839         0.994345
# HBM757.NMDS.629         0.789784         0.801810         0.343351
# HBM782.RNDZ.677         0.666585         0.257815         0.945754
# HBM788.KSZC.942         0.672222         0.433886         0.918252
# HBM796.XJWH.729         0.679016         0.461072         0.898502
# HBM833.VZTL.864         0.734782         0.907511         0.405949
# HBM838.FRWC.772         1.000000         0.635009         0.644792
# HBM853.SNJJ.892         0.635009         1.000000         0.218771
# HBM876.SJWP.278         0.644792         0.218771         1.000000
# HBM937.HPQL.829         0.917569         0.605277         0.527133
# HBM964.XZCR.478         0.360901         0.451427         0.262463
# HBM974.MTJZ.548         0.713536         0.632845         0.307415
# HBM979.SSNH.934         0.760885         0.222133         0.387312
# HBM987.ZCTQ.736         0.841250         0.418765         0.420774
#
#                  HBM937.HPQL.829  HBM964.XZCR.478  HBM974.MTJZ.548  \
# HBM224.HCFB.249         0.951797         0.310534         0.570259
# HBM297.PFXV.394         0.537959         0.267018         0.279662
# HBM336.BZXG.436         0.712862         0.310432         0.684777
# HBM339.DBQF.784         0.925017         0.389799         0.599600
# HBM345.QSPF.289         0.549471         0.586168         0.643909
# HBM434.JDFP.839         0.713221         0.392031         0.615197
# HBM449.THVK.739         0.843088         0.598752         0.694527
# HBM453.BKZB.338         0.604781         0.397354         0.897242
# HBM455.PRVR.965         0.383794         0.231411         0.245595
# HBM486.QXHD.874         0.680042         0.311901         0.605356
# HBM496.GJFX.393         0.484695         0.471874         0.497643
# HBM525.HTJF.586         0.911322         0.230691         0.360523
# HBM534.PQDR.545         0.681187         0.504263         0.741203
# HBM538.RWLX.332         0.441250         0.372015         0.668031
# HBM547.QLDF.845         0.802594         0.337483         0.621098
# HBM556.CFNP.485         0.567622         0.311310         0.444718
# HBM557.PWFN.956         0.453760         0.255872         0.293524
# HBM562.WMRL.498         0.790305         0.292270         0.784868
# HBM566.KXSQ.967         0.409922         0.258939         0.271710
# HBM574.LFRK.262         0.595344         0.297808         0.491294
# HBM587.VWCF.356         0.468829         0.271356         0.338533
# HBM635.PSTJ.637         0.733748         0.282228         0.847826
# HBM638.HSFV.957         0.673148         0.348270         0.487697
# HBM642.VZNT.722         0.688473         0.341053         0.391839
# HBM653.SFTB.462         0.538218         0.082132         0.471060
# HBM667.TFXK.856         0.732366         0.253512         0.293531
# HBM695.TGJS.338         0.147817         0.069578         0.682130
# HBM748.GDSK.748         0.528431         0.319524         0.412555
# HBM752.DHVB.758         0.465846         0.247149         0.246561
# HBM757.NMDS.629         0.702057         0.596658         0.846345
# HBM782.RNDZ.677         0.556743         0.302849         0.338746
# HBM788.KSZC.942         0.583251         0.291911         0.488621
# HBM796.XJWH.729         0.598124         0.292788         0.510271
# HBM833.VZTL.864         0.670636         0.412990         0.814985
# HBM838.FRWC.772         0.917569         0.360901         0.713536
# HBM853.SNJJ.892         0.605277         0.451427         0.632845
# HBM876.SJWP.278         0.527133         0.262463         0.307415
# HBM937.HPQL.829         1.000000         0.277346         0.564375
# HBM964.XZCR.478         0.277346         1.000000         0.223425
# HBM974.MTJZ.548         0.564375         0.223425         1.000000
# HBM979.SSNH.934         0.820953         0.176528         0.212448
# HBM987.ZCTQ.736         0.766942         0.577674         0.535774
#
#                  HBM979.SSNH.934  HBM987.ZCTQ.736
# HBM224.HCFB.249         0.741881         0.731349
# HBM297.PFXV.394         0.438100         0.448241
# HBM336.BZXG.436         0.245108         0.396849
# HBM339.DBQF.784         0.789324         0.846331
# HBM345.QSPF.289         0.390718         0.636534
# HBM434.JDFP.839         0.456790         0.557298
# HBM449.THVK.739         0.630281         0.882114
# HBM453.BKZB.338         0.176416         0.488805
# HBM455.PRVR.965         0.240496         0.298985
# HBM486.QXHD.874         0.277168         0.409948
# HBM496.GJFX.393         0.141736         0.311764
# HBM525.HTJF.586         0.932551         0.798914
# HBM534.PQDR.545         0.243093         0.523733
# HBM538.RWLX.332         0.517120         0.800425
# HBM547.QLDF.845         0.429326         0.524982
# HBM556.CFNP.485         0.289538         0.378341
# HBM557.PWFN.956         0.290989         0.348256
# HBM562.WMRL.498         0.696221         0.843634
# HBM566.KXSQ.967         0.251825         0.310505
# HBM574.LFRK.262         0.276897         0.385410
# HBM587.VWCF.356         0.261860         0.338796
# HBM635.PSTJ.637         0.627763         0.813776
# HBM638.HSFV.957         0.372230         0.452692
# HBM642.VZNT.722         0.894484         0.923904
# HBM653.SFTB.462         0.767595         0.766954
# HBM667.TFXK.856         0.716746         0.644677
# HBM695.TGJS.338         0.217342         0.485361
# HBM748.GDSK.748         0.267164         0.363970
# HBM752.DHVB.758         0.366016         0.388008
# HBM757.NMDS.629         0.368700         0.731417
# HBM782.RNDZ.677         0.399167         0.427799
# HBM788.KSZC.942         0.263327         0.373073
# HBM796.XJWH.729         0.260728         0.375308
# HBM833.VZTL.864         0.219815         0.470966
# HBM838.FRWC.772         0.760885         0.841250
# HBM853.SNJJ.892         0.222133         0.418765
# HBM876.SJWP.278         0.387312         0.420774
# HBM937.HPQL.829         0.820953         0.766942
# HBM964.XZCR.478         0.176528         0.577674
# HBM974.MTJZ.548         0.212448         0.535774
# HBM979.SSNH.934         1.000000         0.807203
# HBM987.ZCTQ.736         0.807203         1.000000
#
# [42 rows x 42 columns]

# %%
import seaborn as sns

sns.clustermap(cos_sim_df, cmap="Blues")
